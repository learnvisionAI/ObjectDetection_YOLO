# %% [markdown]
# <a href="https://colab.research.google.com/github/learnvisionAI/Session1_YOLOv8_Implemtation/blob/main/YOLOv8_Complete_Tutorial_Final_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**YOLOv8 is trained for Object Detection and Image Segmentation and Image Classification Tasks. We will run Object Detection and Image Segementation tasks in this Tutorial**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Before Running The Script, Please Make Sure, You Have Selected the Run Time as GPU

# %% [markdown]
# #**Import the Required Library**

# %%
from IPython.display import Image

# %% [markdown]
# #**Install Ultralytics Library**

# %%
# !pip install ultralytics==8.0.0

# %% [markdown]
# #**Check Whether the GPU is Available or Not**

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.__version__
# Out:
# '2.1.0+cu121'

# %% [markdown]
# #**Download Sample Image and Video From the Google Drive into the Google Colab Notebook**

# %%
# !gdown "https://drive.google.com/uc?id=10t_iEjXEUm8d9Uoam8b-1piXaud1chol&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10t_iEjXEUm8d9Uoam8b-1piXaud1chol&confirm=t
# To: /content/image1.jpg
# 100% 214k/214k [00:00<00:00, 53.5MB/s]

# %%
# !gdown "https://drive.google.com/uc?id=10y1xaKQNqrpFW1ZWvEqAKisrKRlVvAE4&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10y1xaKQNqrpFW1ZWvEqAKisrKRlVvAE4&confirm=t
# To: /content/demo.mp4
# 100% 11.5M/11.5M [00:00<00:00, 46.3MB/s]

# %%
# !gdown "https://drive.google.com/uc?id=160i9mKXgttH8dl75AX67Z0O_W1v6MabY&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=160i9mKXgttH8dl75AX67Z0O_W1v6MabY&confirm=t
# To: /content/image2.jpg
# 100% 180k/180k [00:00<00:00, 112MB/s]

# %% [markdown]
# #**Object Detection**

# %% [markdown]
# #**Run Object Detection on a Sample Image**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image1.jpg'
# Out:
# 2023-12-27 05:18:40.232317: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:18:40.232383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:18:40.233843: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:18:41.288866: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s.pt to yolov8s.pt...
# 100% 21.5M/21.5M [00:00<00:00, 162MB/s]
#
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/image1.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 2 backpacks, 3 handbags, 69.3ms
# Speed: 0.5ms pre-process, 69.3ms inference, 648.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/detect/predict/image1.jpg')

# %% [markdown]
# #**To save the Bounding Box Information set save_txt=True**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image2.jpg' save_txt=True
# Out:
# 2023-12-27 05:19:19.282752: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:19:19.282817: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:19:19.284541: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:19:20.319421: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/image2.jpg: 384x640 3 persons, 4 buss, 69.5ms
# Speed: 0.5ms pre-process, 69.5ms inference, 613.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 1 labels saved to runs/detect/predict2/labels

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/detect/predict2/image2.jpg')

# %% [markdown]
# #**To save the "Crop Object"  set save_crop=True**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image1.jpg' save_crop=True
# Out:
# 2023-12-27 05:19:53.395544: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:19:53.395622: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:19:53.397064: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:19:54.442042: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# image 1/1 /content/image1.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 2 backpacks, 3 handbags, 69.6ms
# Speed: 0.5ms pre-process, 69.6ms inference, 494.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/detect/predict3/crops/person/image16.jpg')

# %% [markdown]
# #**To remove the confidence values and labels, we will use hide_labels and hide_conf Flags**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image1.jpg' hide_labels=True hide_conf=True
# Out:
# 2023-12-27 05:20:07.644095: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:20:07.644144: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:20:07.645520: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:20:08.689489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/image1.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 2 backpacks, 3 handbags, 125.0ms
# Speed: 0.7ms pre-process, 125.0ms inference, 703.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/detect/predict4/image1.jpg')

# %% [markdown]
# #**Run Object Detection on Videos**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/demo.mp4'

# %% [markdown]
# #**Display the Demo Video**

# %%
# !rm "/content/result_compressed.mp4"
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict5/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #**Image Segmentation**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/image2.jpg'
# Out:
# 2023-12-27 05:26:45.550144: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:26:45.550204: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:26:45.551674: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:26:46.585888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8s-seg.pt to yolov8s-seg.pt...
# 100% 22.8M/22.8M [00:00<00:00, 167MB/s]
#
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# image 1/1 /content/image2.jpg: 384x640 3 persons, 4 buss, 88.9ms
# Speed: 0.4ms pre-process, 88.9ms inference, 552.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %% [markdown]
# #**Dispay the Output Image**

# %%
Image('/content/runs/segment/predict/image2.jpg')

# %% [markdown]
# #**Hide Labels and Confidence Value**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/image2.jpg'  hide_labels=True hide_conf=True
# Out:
# 2023-12-27 05:27:14.338516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-27 05:27:14.338574: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-27 05:27:14.340323: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-27 05:27:15.818149: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/image2.jpg: 384x640 3 persons, 4 buss, 88.0ms
# Speed: 0.5ms pre-process, 88.0ms inference, 665.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict2

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/segment/predict2/image2.jpg')

# %% [markdown]
# #**Run Segmentation on Video**

# %%
# !yolo task=segment mode=predict model=yolov8s-seg.pt source='/content/demo.mp4'

# %% [markdown]
# #**Display the Output Video for Segmentation**

# %%
# !rm  "/content/result_compressed.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/segment/predict3/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #**Export Model in ONNX Format**

# %% [markdown]
# #**Detection**

# %%
# !yolo task=detect mode=export model=yolov8s.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# PyTorch: starting from yolov8s.pt with output shape (1, 84, 8400) (21.5 MB)
# requirements: YOLOv5 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting onnx>=1.12.0
#   Downloading onnx-1.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 90.0 MB/s eta 0:00:00
# Collecting protobuf<4,>=3.20.2
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.12.0) (4.5.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.12.0) (1.22.4)
# Installing collected packages: protobuf, onnx
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# Successfully installed onnx-1.13.1 protobuf-3.20.3
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success ✅ 11.2s, saved as yolov8s.onnx (42.8 MB)
#
# Export complete (12.9s)
# Results saved to /content
# Predict:         yolo task=detect mode=predict model=yolov8s.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Validate:        yolo task=detect mode=val model=yolov8s.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Visualize:       https://netron.app

# %% [markdown]
# #**Segmentation**

# %%
# !yolo task=segment mode=export model=yolov8s-seg.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# Fusing layers...
# YOLOv8s-seg summary: 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# PyTorch: starting from yolov8s-seg.pt with output shape (1, 116, 8400) (22.8 MB)
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success ✅ 1.5s, saved as yolov8s-seg.onnx (45.3 MB)
#
# Export complete (2.8s)
# Results saved to /content
# Predict:         yolo task=segment mode=predict model=yolov8s-seg.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Validate:        yolo task=segment mode=val model=yolov8s-seg.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Visualize:       https://netron.app

# %% [markdown]
# #**To Do All this in Python Instead of Command Line**

# %% [markdown]
# #**For Image**

# %%
from ultralytics import YOLO

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m.pt")
#Predict Method Takes all the parameters of the Command Line Interface
model.predict(source='/content/image1.jpg',  save=True, conf=0.5,save_txt=True)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt to yolov8m.pt...
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]
# Ultralytics YOLOv8.0.0 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# YOLOv8m summary: 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
# image 1/1 /content/image1.jpg: 448x640 11 persons, 1 bicycle, 1 bus, 1 traffic light, 1 backpack, 3 handbags, 97.7ms
# Speed: 0.5ms pre-process, 97.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6
# 1 labels saved to runs/detect/predict6/labels
# [tensor([[2.24000e+02, 3.09000e+02, 4.34000e+02, 6.59000e+02, 9.11621e-01, 0.00000e+00],
#          [9.44000e+02, 3.37000e+02, 1.00000e+03, 5.55000e+02, 9.02344e-01, 0.00000e+00],
#          [7.38000e+02, 3.37000e+02, 8.70000e+02, 6.61000e+02, 8.90625e-01, 0.00000e+00],
#          [2.96000e+02, 1.75000e+02, 7.79000e+02, 4.67000e+02, 8.90137e-01, 5.00000e+00],
#          [5.89000e+02, 3.67000e+02, 6.72000e+02, 6.61000e+02, 8.75977e-01, 0.00000e+00],
#          [4.38000e+02, 3.71000e+02, 5.58000e+02, 6.59000e+02, 8.56934e-01, 0.00000e+00],
#          [3.02000e+02, 4.02000e+02, 4.32000e+02, 6.12000e+02, 8.32031e-01, 2.40000e+01],
#          [8.36000e+02, 3.48000e+02, 9.09000e+02, 6.39000e+02, 7.88086e-01, 0.00000e+00],
#          [6.97000e+02, 8.70000e+01, 8.29000e+02, 2.73000e+02, 7.73438e-01, 9.00000e+00],
#          [4.74000e+02, 4.27000e+02, 5.54000e+02, 5.65000e+02, 7.37305e-01, 2.60000e+01],
#          [6.58000e+02, 4.32000e+02, 7.14000e+02, 5.38000e+02, 7.12402e-01, 2.60000e+01],
#          [8.00000e+00, 3.35000e+02, 4.00000e+01, 4.08000e+02, 6.68945e-01, 0.00000e+00],
#          [3.90000e+01, 3.39000e+02, 6.90000e+01, 4.10000e+02, 6.46973e-01, 0.00000e+00],
#          [1.00000e+00, 4.41000e+02, 7.70000e+01, 6.59000e+02, 6.45996e-01, 0.00000e+00],
#          [3.91000e+02, 5.89000e+02, 5.06000e+02, 6.62000e+02, 6.27930e-01, 1.00000e+00],
#          [5.54000e+02, 4.69000e+02, 5.99000e+02, 5.57000e+02, 6.18652e-01, 2.60000e+01],
#          [2.35000e+02, 3.41000e+02, 2.52000e+02, 3.92000e+02, 6.16211e-01, 0.00000e+00],
#          [0.00000e+00, 3.36000e+02, 1.60000e+01, 4.05000e+02, 5.34180e-01, 0.00000e+00]], device='cuda:0')]

# %% [markdown]
# #**Display the Output Image**

# %%
Image('/content/runs/detect/predict6/image1.jpg')

# %% [markdown]
# #**For Video**

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m.pt")
#Predict Method Takes all the parameters of the Command Line Interface
model.predict(source='/content/demo.mp4',  save=True, conf=0.5, save_txt = False)

# %% [markdown]
# #**Display the Output Video**

# %%
# !rm "/content/result_compressed.mp4"
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict7/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %% [markdown]
# #**To Export the Model in the onnx Format comment model.predict line and add the model.export()**

# %%
#Initialize YOLO with the model name
model = YOLO("yolov8m.pt")
#Export the Model in the onnx format
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# half=True only compatible with GPU or CoreML export, i.e. use device=0 or format=coreml
# Fusing layers...
# YOLOv8m summary: 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#
# PyTorch: starting from yolov8m.pt with output shape (1, 84, 8400) (49.7 MB)
# requirements: YOLOv5 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: onnx>=1.12.0 in /usr/local/lib/python3.8/dist-packages (1.13.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.12.0) (4.5.0)
# Requirement already satisfied: protobuf<4,>=3.20.2 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.12.0) (3.20.3)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.8/dist-packages (from onnx>=1.12.0) (1.22.4)
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.13.1...
# ONNX: export success ✅ 6.7s, saved as yolov8m.onnx (99.0 MB)
#
# Export complete (10.4s)
# Results saved to /content
# Predict:         yolo task=detect mode=predict model=yolov8m.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Validate:        yolo task=detect mode=val model=yolov8m.onnx -WARNING ⚠️ not yet supported for YOLOv8 exported models
# Visualize:       https://netron.app
