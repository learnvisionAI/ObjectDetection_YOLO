# %% [markdown]
# <a href="https://colab.research.google.com/github/learnvisionAI/ObjectDetection_YOLO/blob/main/Session1_YOLOV8_ObjectTracking/ObjectTracking_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AarohiSingla/Vehicle-Couning.git
# Out:
# Cloning into 'Vehicle-Couning'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 3), reused 8 (delta 0), pack-reused 0
# Receiving objects: 100% (15/15), 4.07 MiB | 25.72 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# %cd /content/Vehicle-Couning
# Out:
# /content/Vehicle-Couning

# %%
# !pip install ultralytics
# !pip install supervision

import supervision
print("supervision.__version__:", supervision.__version__)

import ultralytics
ultralytics.__version__
# Out:
# ...
# '8.0.230'

# %%
# Out:
# supervision.__version__: 0.17.1

# %%
import torch
torch.__version__
# Out:
# '2.1.0+cu121'

# %%
from ultralytics import YOLO

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')

results = model.track(source="/content/demo.mp4",conf=0.3, iou=0.5, save=True, tracker="bytetrack.yaml")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 93.0MB/s]
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1314) /content/demo.mp4: 384x640 1 car, 274.2ms
# video 1/1 (2/1314) /content/demo.mp4: 384x640 1 car, 175.3ms
# video 1/1 (3/1314) /content/demo.mp4: 384x640 1 car, 174.7ms
# video 1/1 (4/1314) /content/demo.mp4: 384x640 1 car, 209.2ms
# video 1/1 (5/1314) /content/demo.mp4: 384x640 1 car, 191.4ms
# video 1/1 (6/1314) /content/demo.mp4: 384x640 2 cars, 165.3ms
# ...
